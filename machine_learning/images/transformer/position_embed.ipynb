# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

matplotlib.rc("font", size=SMALL_SIZE)          # controls default text sizes
matplotlib.rc("axes", titlesize=MEDIUM_SIZE)     # fontsize of the axes title
matplotlib.rc("axes", labelsize=SMALL_SIZE)    # fontsize of the x and y labels
matplotlib.rc("xtick", labelsize=SMALL_SIZE)    # fontsize of the tick labels
matplotlib.rc("ytick", labelsize=SMALL_SIZE)    # fontsize of the tick labels
matplotlib.rc("legend", fontsize=SMALL_SIZE)    # legend fontsize
matplotlib.rc("figure", titlesize=MEDIUM_SIZE)  # fontsize of the figure title

# %%
num_tokens = 256
d_embed = 64
N = 10_000
PE = [[np.sin(x/np.power(N, i/d_embed)) if i%2==0 
       else np.cos(x/np.power(N, (i-1)/d_embed))
       for x in range(num_tokens)] for i in range(d_embed)]

# %%
fig, ax = plt.subplots(figsize=(9/2.54, 7/2.54))
pc = ax.pcolormesh(PE, cmap="seismic")
pc.set_clim(-1, 1)
cbar = fig.colorbar(pc, label="Positional encoding")
ax.set_xlabel("Position $i$")
ax.set_ylabel("Feature $j$")
fig.savefig("positional_encoding.png", bbox_inches="tight", dpi=300)

# %%
num_tokens = 10_000
d_embed = 64
N = 10_000
PE = [[np.sin((x+1)/np.power(N, i/(d_embed-1))) if i%2==0 
       else np.cos((x+1)/np.power(N, i/(d_embed-1))) 
       for x in range(num_tokens)] for i in range(d_embed)]

# %%
fig, ax = plt.subplots(figsize=(10/2.54, 4/2.54))
pc = ax.pcolormesh(PE, cmap="seismic")
pc.set_clim(-1, 1)
cbar = fig.colorbar(pc, label="Positional encoding")
ax.set_xlabel("Position $x$")
ax.set_ylabel("Embedding $i$")
# Out:
# Text(0, 0.5, 'Embedding $i$')
