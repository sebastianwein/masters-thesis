# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

matplotlib.rc("font", size=SMALL_SIZE)          # controls default text sizes
matplotlib.rc("axes", titlesize=MEDIUM_SIZE)     # fontsize of the axes title
matplotlib.rc("axes", labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
matplotlib.rc("xtick", labelsize=SMALL_SIZE)    # fontsize of the tick labels
matplotlib.rc("ytick", labelsize=SMALL_SIZE)    # fontsize of the tick labels
matplotlib.rc("legend", fontsize=SMALL_SIZE)    # legend fontsize
matplotlib.rc("figure", titlesize=MEDIUM_SIZE)  # fontsize of the figure title

# %%
def g_func(theta):
    return (1+np.cos(theta)**2)**2 + np.cos(theta)**2

# %%
theta = np.linspace(0, 2*np.pi, 1000)
g = g_func(theta)

# %%
fig, ax = plt.subplots(figsize=(4/2.54, 8/2.54))
x, y = g*np.cos(theta-np.pi/2), g*np.sin(theta-np.pi/2)
ax.plot(x, y)
ax.set_aspect("equal", adjustable="box")
plt.draw()
xlim = ax.get_xlim()
ylim = ax.get_ylim()
ax.plot(xlim, [0, 0], c="k", lw=0.75, zorder=-10)
ax.plot([0, 0], ylim, c="k", lw=0.75, zorder=-10)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.set_xticks([])
ax.set_yticks([])
ax.xaxis.set_label_position("top") 
ax.set_xlabel(r"z-axis")
ax.yaxis.set_label_position("right") 
ax.set_ylabel("x–y plane", va="center", ha="left", rotation=0)
fig.tight_layout()
fig.savefig("radiation_pattern.png", dpi=300, bbox_inches="tight")
